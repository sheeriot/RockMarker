# %%
import folium
import pandas as pd

# %%
# Setup input file and center of map for intended output

rocks = pd.read_csv('sites/eaglelake/rocks.csv')
# Eagle Lake: 44.683,-76.7
center_lat, center_lon = 44.683,-76.7
# set map bounds, SW, NE corners
# sw_corner = (44.66, -76.72)
# ne_corner = (44.7, -76.68)
# bounds = [sw_corner, ne_corner]

# %%
# Create a Folium map1 object with the specified center and zoom
map1 = folium.Map(location=[center_lat, center_lon],zoom_start=14)

# use satellite imagery from ESRI
folium.TileLayer(
    tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr = 'Esri',
    name = 'Esri Satellite',
    overlay = False,
).add_to(map1)

# map1.fit_bounds(bounds)

# Iterate over the rows of the data and add markers to the map
for index, row in rocks.iterrows():
    lat = row['latitude']
    long = row['longitude']
    name = row['nickname']
    marker = folium.CircleMarker(
        location=[lat, long], 
        tooltip=name, 
        color='red', 
        fill=True, 
        fill_color='red',
        fill_opacity=0.4,
        radius=3
    )
    marker.add_to(map1)

# Display and save map1
map1.save('sites/eaglelake/map1.html')
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72fa66744395da83582b5733cb293e91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72fa66744395da83582b5733cb293e91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72fa66744395da83582b5733cb293e91 = L.map(
#                 &quot;map_72fa66744395da83582b5733cb293e91&quot;,
#                 {
#                     center: [44.683, -76.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_456dc13159f255e0a263257631c26276 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_456dc13159f255e0a263257631c26276.addTo(map_72fa66744395da83582b5733cb293e91);
#
#             var tile_layer_6ae6a53f397d041430ae0cd5750224ed = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6ae6a53f397d041430ae0cd5750224ed.addTo(map_72fa66744395da83582b5733cb293e91);
#
#             var circle_marker_607ceccaf0d0510ed6fb5129b39e55ca = L.circleMarker(
#                 [44.693667, -76.713394],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72fa66744395da83582b5733cb293e91);
#
#
#             circle_marker_607ceccaf0d0510ed6fb5129b39e55ca.bindTooltip(
#                 `&lt;div&gt;
#                      dirty1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e4b065064d0ed9caeea4bd0f9f9b2b90 = L.circleMarker(
#                 [44.688038, -76.690349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72fa66744395da83582b5733cb293e91);
#
#
#             circle_marker_e4b065064d0ed9caeea4bd0f9f9b2b90.bindTooltip(
#                 `&lt;div&gt;
#                      dirty2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_6726267d0f320edb2b4668d8931aaa09 = L.circleMarker(
#                 [44.693773, -76.68964],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72fa66744395da83582b5733cb293e91);
#
#
#             circle_marker_6726267d0f320edb2b4668d8931aaa09.bindTooltip(
#                 `&lt;div&gt;
#                      dirty3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_5754e5fbc2e4263e9f2aad1b1270ed6c = L.circleMarker(
#                 [44.693331, -76.688868],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72fa66744395da83582b5733cb293e91);
#
#
#             circle_marker_5754e5fbc2e4263e9f2aad1b1270

# %%
# Create a Folium map object with the specified center
map2 = folium.Map(location=[center_lat, center_lon],zoom_start=14)
folium.TileLayer(
    tiles='http://{s}.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
    attr='google',
    name='google maps',
    max_zoom=16,
    subdomains=['mt0', 'mt1', 'mt2', 'mt3'],
    control=True
).add_to(map2)


# Iterate over the rows of the data and add markers to the map
for index, row in rocks.iterrows():
    lat = row['latitude']
    long = row['longitude']
    name = row['nickname']
    # marker = folium.CircleMarker(location=[lat, long], tooltip=name)
    marker = folium.Marker(
        location=[lat, long],
        tooltip=name,
        icon=folium.Icon(color="red",icon="exclamation-triangle", prefix='fa')
    )
    marker.add_to(map2)
    
# Display map2

map2.save('sites/eaglelake/map2.html')
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b8ae68a4fc5bc792ec351b57f1933cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b8ae68a4fc5bc792ec351b57f1933cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b8ae68a4fc5bc792ec351b57f1933cd = L.map(
#                 &quot;map_7b8ae68a4fc5bc792ec351b57f1933cd&quot;,
#                 {
#                     center: [44.683, -76.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edb22f05b05b59b4798a4181dbdbbd20 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_edb22f05b05b59b4798a4181dbdbbd20.addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#             var tile_layer_5241ad5c1eaf6d48951d2d9b37c408a5 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 16, &quot;maxZoom&quot;: 16, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: [&quot;mt0&quot;, &quot;mt1&quot;, &quot;mt2&quot;, &quot;mt3&quot;], &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_5241ad5c1eaf6d48951d2d9b37c408a5.addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#             var marker_146f6bfab62a2ac53b9cb9c2ca3da361 = L.marker(
#                 [44.693667, -76.713394],
#                 {}
#             ).addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#
#             var icon_2a0cbd87cd120385011ff89ebbaa89cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-triangle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_146f6bfab62a2ac53b9cb9c2ca3da361.setIcon(icon_2a0cbd87cd120385011ff89ebbaa89cc);
#
#
#             marker_146f6bfab62a2ac53b9cb9c2ca3da361.bindTooltip(
#                 `&lt;div&gt;
#                      dirty1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0d8c37e088af1c5109c0833dd39a8deb = L.marker(
#                 [44.688038, -76.690349],
#                 {}
#             ).addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#
#             var icon_673a2f2f241b5b9bc9573b30ed637acc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-triangle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0d8c37e088af1c5109c0833dd39a8deb.setIcon(icon_673a2f2f241b5b9bc9573b30ed637acc);
#
#
#             marker_0d8c37e088af1c5109c0833dd39a8deb.bindTooltip(
#                 `&lt;div&gt;
#                      dirty2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fa84c87572b265884020be77add861a = L.marker(
#                 [44.693773, -76.68964],
#                 {}
#             ).addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#
#             var icon_90a7c9ac8bfcdd51ac91b2f4cf9db170 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-triangle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8fa84c87572b265884020be77add861a.setIcon(icon_90a7c9ac8bfcdd51ac91b2f4cf9db170);
#
#
#             marker_8fa84c87572b265884020be77add861a.bindTooltip(
#                 `&lt;div&gt;
#                      dirty3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4d15a85517600ee0e4840156017612a = L.marker(
#                 [44.693331, -76.688868],
#                 {}
#             ).addTo(map_7b8ae68a4fc5bc792ec351b57f1933cd);
#
#
#             var icon_e54404c11bd0103ef38b9b9ca0472896 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-triangle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f4d15a85517600ee0e4840156017612a.setIcon(icon_e54404c11bd0103ef38b9b9ca0472896);
#
#
#             marker_f4d15a85517600ee0e4840156017612a.bindTooltip(
#                 `&lt;div&gt;
